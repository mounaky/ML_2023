# %% [markdown]
# <a href="https://colab.research.google.com/github/mounaky/ML_2023/blob/main/ML_Car_Price_1_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset.
training_df = pd.read_csv('/content/ML_Car_Price_1.csv')


# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#     Year    Kms  Showroom_Price  Present_Price
# 0 2000.0 1000.0             5.0            5.0
# 1 2000.0 2000.0             5.0            4.9
# 2 2000.0 3000.0             5.0            4.9
# 3 2000.0 4000.0             5.0            4.9
# 4 2000.0 5000.0             5.0            4.8

# %%
#check for presence of None in any column of the dataframe
print(training_df.isnull().values.any())

#provides sum of NA from each column
training_df.isna().sum()
# Out:
# True
# Year              2
# Kms               2
# Showroom_Price    2
# Present_Price     2
# dtype: int64

# %%
# dropna(inplace = True) will remove all rows containing NULL values from the original DataFrame.
training_df.dropna(inplace = True)

# %%
#To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row.
print(training_df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# Length: 138, dtype: bool

# %%
#Remove all duplicates: The (inplace = True) will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame.
training_df.drop_duplicates(inplace = True)

# %%
#check for presence of None in any column of the dataframe
print(training_df.isnull().values.any())

#provides sum of NA from each column
training_df.isna().sum()
# Out:
# False
# Year              0
# Kms               0
# Showroom_Price    0
# Present_Price     0
# dtype: int64

# %%
#To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row.
print(training_df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# Length: 136, dtype: bool

# %%
# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#     Year    Kms  Showroom_Price  Present_Price
# 0 2000.0 1000.0             5.0            5.0
# 1 2000.0 2000.0             5.0            4.9
# 2 2000.0 3000.0             5.0            4.9
# 3 2000.0 4000.0             5.0            4.9
# 4 2000.0 5000.0             5.0            4.8

# %%
training_df.corr()
# Out:
#                 Year  Kms  Showroom_Price  Present_Price
# Year             NaN  NaN             NaN            NaN
# Kms              NaN  1.0             NaN           -1.0
# Showroom_Price   NaN  NaN             NaN            NaN
# Present_Price    NaN -1.0             NaN            1.0

# %%
#Delete column 'Year' as it has no correlation with other data and can't be used for training and prediction
del training_df['Year']
del training_df['Showroom_Price']
print(training_df)
training_df.corr()
# Out:
#          Kms  Present_Price
# 0     1000.0            5.0
# 1     2000.0            4.9
# 2     3000.0            4.9
# 3     4000.0            4.9
# 4     5000.0            4.8
# ..       ...            ...
# 135 132000.0            0.6
# 136 133000.0            0.6
# 137 134000.0            0.5
# 138 135000.0            0.5
# 139 136000.0            0.5
#
# [136 rows x 2 columns]
#                Kms  Present_Price
# Kms            1.0           -1.0
# Present_Price -1.0            1.0

# %%
# Get statistics on the dataset.
training_df.describe()
# Out:
#            Kms  Present_Price
# count    136.0          136.0
# mean   68500.0            2.7
# std    39403.9            1.3
# min     1000.0            0.5
# 25%    34750.0            1.6
# 50%    68500.0            2.7
# 75%   102250.0            3.8
# max   136000.0            5.0

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 100 random points of the dataset.
  random_examples = training_df.sample(n=100)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = random_examples[feature].max()
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.03
epochs = 50
batch_size = 5

# Specify the feature and the label.

#########################################################################
#First execute without below line and observe that predication doesn't match actual values 
#as Kms is a large number compared to Present_Price
#training_df['Kms']=training_df['Kms']/1000

#########################################################################

my_feature = "Kms"  # the total number of rooms on a specific city block.
my_label="Present_Price" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 1s 2ms/step - loss: 16849856.0000 - root_mean_squared_error: 4104.8574
# Epoch 2/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1775737.6250 - root_mean_squared_error: 1332.5680
# Epoch 3/50
# 28/28 [==============================] - 0s 1ms/step - loss: 495766.7500 - root_mean_squared_error: 704.1071
# Epoch 4/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1352035.5000 - root_mean_squared_error: 1162.7706
# Epoch 5/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1107147.2500 - root_mean_squared_error: 1052.2107
# Epoch 6/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1470119.2500 - root_mean_squared_error: 1212.4847
# Epoch 7/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1056479.0000 - root_mean_squared_error: 1027.8517
# Epoch 8/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1501829.7500 - root_mean_squared_error: 1225.4916
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1014026.8125 - root_mean_squared_error: 1006.9890
# Epoch 10/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1262280.6250 - root_mean_squared_error: 1123.5126
# Epoch 11/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1210480.0000 - root_mean_squared_error: 1100.2181
# Epoch 12/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1264624.3750 - root_mean_squared_error: 1124.5552
# Epoch 13/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1177073.2500 - root_mean_squared_error: 1084.9301
# Epoch 14/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1388115.2500 - root_mean_squared_error: 1178.1830
# Epoch 15/50
# 28/28 [==============================] - 0s 1ms/step - loss: 674932.1875 - root_mean_squared_error: 821.5425
# Epoch 16/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1062175.2500 - root_mean_squared_error: 1030.6189
# Epoch 17/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1222705.3750 - root_mean_squared_error: 1105.7601
# Epoch 18/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1215220.0000 - root_mean_squared_error: 1102.3701
# Epoch 19/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1235132.2500 - root_mean_squared_error: 1111.3650
# Epoch 20/50
# 28/28 [==============================] - 0s 1ms/step - loss: 2024071.7500 - root_mean_squared_error: 1422.6987
# Epoch 21/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1121377.6250 - root_mean_squared_error: 1058.9512
# Epoch 22/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1183494.8750 - root_mean_squared_error: 1087.8855
# Epoch 23/50
# 28/28 [==============================] - 0s 2ms/step - loss: 294759.7812 - root_mean_squared_error: 542.9178
# Epoch 24/50
# 28/28 [==============================] - 0s 1ms/step - loss: 2012021.8750 - root_mean_squared_error: 1418.4575
# Epoch 25/50
# 28/28 [==============================] - 0s 1ms/step - loss: 665772.4375 - root_mean_squared_error: 815.9488
# Epoch 26/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1188558.8750 - root_mean_squared_error: 1090.2104
# Epoch 27/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1502388.1250 - root_mean_squared_error: 1225.7195
# Epoch 28/50
# 28/28 [==============================] - 0s 1ms/step - loss: 875557.3125 - root_mean_squared_error: 935.7122
# Epoch 29/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1120958.2500 - root_mean_squared_error: 1058.7532
# Epoch 30/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1182148.6250 - root_mean_squared_error: 1087.2666
# Epoch 31/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1333669.8750 - root_mean_squared_error: 1154.8463
# Epoch 32/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1348680.8750 - root_mean_squared_error: 1161.3271
# Epoch 33/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1172898.3750 - root_mean_squared_error: 1083.0043
# Epoch 34/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1347329.3750 - root_mean_squared_error: 1160.7452
# Epoch 35/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1052338.8750 - root_mean_squared_error: 1025.8357
# Epoch 36/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1264783.1250 - root_mean_squared_error: 1124.6257
# Epoch 37/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1419683.6250 - root_mean_squared_error: 1191.5048
# Epoch 38/50
# 28/28 [==============================] - 0s 1ms/step - loss: 882078.6875 - root_mean_squared_error: 939.1904
# Epoch 39/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1663073.0000 - root_mean_squared_error: 1289.6019
# Epoch 40/50
# 28/28 [==============================] - 0s 1ms/step - loss: 799148.5000 - root_mean_squared_error: 893.9510
# Epoch 41/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1327201.5000 - root_mean_squared_error: 1152.0424
# Epoch 42/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1498007.8750 - root_mean_squared_error: 1223.9313
# Epoch 43/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1031746.1250 - root_mean_squared_error: 1015.7490
# Epoch 44/50
# 28/28 [==============================] - 0s 1ms/step - loss: 955192.0000 - root_mean_squared_error: 977.3392
# Epoch 45/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1170652.8750 - root_mean_squared_error: 1081.9672
# Epoch 46/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1422778.8750 - root_mean_squared_error: 1192.8030
# Epoch 47/50
# 28/28 [==============================] - 0s 1ms/step - loss: 846818.2500 - root_mean_squared_error: 920.2273
# Epoch 48/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1266906.2500 - root_mean_squared_error: 1125.5693
# Epoch 49/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1234792.5000 - root_mean_squared_error: 1111.2122
# Epoch 50/50
# 28/28 [==============================] - 0s 1ms/step - loss: 1373707.7500 - root_mean_squared_error: 1172.0527
#
# The learned weight for your model is 0.0017
# The learned bias for your model is -0.1333
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
plt.plot(training_df['Kms'],training_df['Present_Price'])

# %%
def predict_car_values(n, feature, label):
  """Predict car values based on a feature."""

  batch = training_df[feature][100:100 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature      label          predicted")
  print("  kms     SellingPrice        price  ")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.2f %6.2f %15.2f" % (training_df[feature][100 + i],
                                   training_df[label][100 + i],
                                   predicted_values[i][0] ))

# %%
predict_car_values(5, my_feature, my_label)
# Out:
# feature      label          predicted
#   kms     SellingPrice        price
# --------------------------------------
# 98000.00   1.73          170.60
# 99000.00   1.70          172.29
# 100000.00   1.67          173.98
# 101000.00   1.63          175.67
# 102000.00   1.60          177.36

# %%
# Define a synthetic feature
training_df["kms_scaled_1000"] = training_df["Kms"]/1000

training_df["Synthetic_Feature"] = training_df["kms_scaled_1000"]

my_feature = "Synthetic_Feature"
my_label="Present_Price"

print(training_df)

# Tune the hyperparameters.

#learning_rate = 0.005(correct)
learning_rate = 0.006

#epochs = 150(correct)
epochs = 200

#batch_size = 10(correct)
batch_size = 10

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, mae = train_model(my_model, training_df,
                                        my_feature, my_label,
                                        epochs, batch_size)

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, mae)
predict_car_values(5, my_feature, my_label)
# Out:
#          Kms  Present_Price  kms_scaled_1000  Synthetic_Feature
# 0     1000.0            5.0              1.0                1.0
# 1     2000.0            4.9              2.0                2.0
# 2     3000.0            4.9              3.0                3.0
# 3     4000.0            4.9              4.0                4.0
# 4     5000.0            4.8              5.0                5.0
# ..       ...            ...              ...                ...
# 135 132000.0            0.6            132.0              132.0
# 136 133000.0            0.6            133.0              133.0
# 137 134000.0            0.5            134.0              134.0
# 138 135000.0            0.5            135.0              135.0
# 139 136000.0            0.5            136.0              136.0
#
# [136 rows x 4 columns]
# Epoch 1/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5294.3867 - root_mean_squared_error: 72.7625
# Epoch 2/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4241.3179 - root_mean_squared_error: 65.1254
# Epoch 3/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3458.9900 - root_mean_squared_error: 58.8132
# Epoch 4/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2772.8965 - root_mean_squared_error: 52.6583
# Epoch 5/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2174.3027 - root_mean_squared_error: 46.6294
# Epoch 6/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1675.0492 - root_mean_squared_error: 40.9274
# Epoch 7/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1229.5955 - root_mean_squared_error: 35.0656
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 867.7372 - root_mean_squared_error: 29.4574
# Epoch 9/200
# 14/14 [==============================] - 0s 2ms/step - loss: 570.7033 - root_mean_squared_error: 23.8894
# Epoch 10/200
# 14/14 [==============================] - 0s 2ms/step - loss: 338.8225 - root_mean_squared_error: 18.4071
# Epoch 11/200
# 14/14 [==============================] - 0s 2ms/step - loss: 176.6538 - root_mean_squared_error: 13.2911
# Epoch 12/200
# 14/14 [==============================] - 0s 2ms/step - loss: 74.8171 - root_mean_squared_error: 8.6497
# Epoch 13/200
# 14/14 [==============================] - 0s 2ms/step - loss: 22.2674 - root_mean_squared_error: 4.7188
# Epoch 14/200
# 14/14 [==============================] - 0s 2ms/step - loss: 5.8634 - root_mean_squared_error: 2.4214
# Epoch 15/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.9612 - root_mean_squared_error: 1.9903
# Epoch 16/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.9019 - root_mean_squared_error: 1.9753
# Epoch 17/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.7274 - root_mean_squared_error: 1.9306
# Epoch 18/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.7818 - root_mean_squared_error: 1.9447
# Epoch 19/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.5300 - root_mean_squared_error: 1.8788
# Epoch 20/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.4613 - root_mean_squared_error: 1.8605
# Epoch 21/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.2355 - root_mean_squared_error: 1.7988
# Epoch 22/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1523 - root_mean_squared_error: 1.7755
# Epoch 23/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1441 - root_mean_squared_error: 1.7732
# Epoch 24/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.9182 - root_mean_squared_error: 1.7083
# Epoch 25/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8645 - root_mean_squared_error: 1.6925
# Epoch 26/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7008 - root_mean_squared_error: 1.6434
# Epoch 27/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6821 - root_mean_squared_error: 1.6377
# Epoch 28/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4877 - root_mean_squared_error: 1.5773
# Epoch 29/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3781 - root_mean_squared_error: 1.5421
# Epoch 30/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3769 - root_mean_squared_error: 1.5417
# Epoch 31/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1806 - root_mean_squared_error: 1.4767
# Epoch 32/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1702 - root_mean_squared_error: 1.4732
# Epoch 33/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0072 - root_mean_squared_error: 1.4167
# Epoch 34/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8558 - root_mean_squared_error: 1.3623
# Epoch 35/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7734 - root_mean_squared_error: 1.3317
# Epoch 36/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7544 - root_mean_squared_error: 1.3246
# Epoch 37/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7400 - root_mean_squared_error: 1.3191
# Epoch 38/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5168 - root_mean_squared_error: 1.2316
# Epoch 39/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5434 - root_mean_squared_error: 1.2423
# Epoch 40/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4036 - root_mean_squared_error: 1.1847
# Epoch 41/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3103 - root_mean_squared_error: 1.1447
# Epoch 42/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2653 - root_mean_squared_error: 1.1249
# Epoch 43/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1817 - root_mean_squared_error: 1.0871
# Epoch 44/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1058 - root_mean_squared_error: 1.0516
# Epoch 45/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0693 - root_mean_squared_error: 1.0340
# Epoch 46/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0523 - root_mean_squared_error: 1.0258
# Epoch 47/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8886 - root_mean_squared_error: 0.9427
# Epoch 48/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8396 - root_mean_squared_error: 0.9163
# Epoch 49/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8210 - root_mean_squared_error: 0.9061
# Epoch 50/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7525 - root_mean_squared_error: 0.8675
# Epoch 51/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6760 - root_mean_squared_error: 0.8222
# Epoch 52/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6879 - root_mean_squared_error: 0.8294
# Epoch 53/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6162 - root_mean_squared_error: 0.7850
# Epoch 54/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5889 - root_mean_squared_error: 0.7674
# Epoch 55/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5037 - root_mean_squared_error: 0.7097
# Epoch 56/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4847 - root_mean_squared_error: 0.6962
# Epoch 57/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4121 - root_mean_squared_error: 0.6419
# Epoch 58/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4045 - root_mean_squared_error: 0.6360
# Epoch 59/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3647 - root_mean_squared_error: 0.6039
# Epoch 60/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3352 - root_mean_squared_error: 0.5790
# Epoch 61/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3309 - root_mean_squared_error: 0.5752
# Epoch 62/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2898 - root_mean_squared_error: 0.5384
# Epoch 63/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2424 - root_mean_squared_error: 0.4924
# Epoch 64/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2397 - root_mean_squared_error: 0.4896
# Epoch 65/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1971 - root_mean_squared_error: 0.4440
# Epoch 66/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2061 - root_mean_squared_error: 0.4540
# Epoch 67/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1269 - root_mean_squared_error: 0.3563
# Epoch 68/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1903 - root_mean_squared_error: 0.4362
# Epoch 69/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1548 - root_mean_squared_error: 0.3934
# Epoch 70/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1697 - root_mean_squared_error: 0.4119
# Epoch 71/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0936 - root_mean_squared_error: 0.3059
# Epoch 72/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1045 - root_mean_squared_error: 0.3232
# Epoch 73/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1180 - root_mean_squared_error: 0.3435
# Epoch 74/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1047 - root_mean_squared_error: 0.3235
# Epoch 75/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0736 - root_mean_squared_error: 0.2713
# Epoch 76/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1031 - root_mean_squared_error: 0.3211
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0840 - root_mean_squared_error: 0.2898
# Epoch 78/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0612 - root_mean_squared_error: 0.2474
# Epoch 79/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0681 - root_mean_squared_error: 0.2609
# Epoch 80/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0638 - root_mean_squared_error: 0.2526
# Epoch 81/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0916 - root_mean_squared_error: 0.3026
# Epoch 82/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0697 - root_mean_squared_error: 0.2640
# Epoch 83/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0744 - root_mean_squared_error: 0.2728
# Epoch 84/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0275 - root_mean_squared_error: 0.1658
# Epoch 85/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0638 - root_mean_squared_error: 0.2526
# Epoch 86/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0858 - root_mean_squared_error: 0.2928
# Epoch 87/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406
# Epoch 88/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0717 - root_mean_squared_error: 0.2677
# Epoch 89/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0517 - root_mean_squared_error: 0.2273
# Epoch 90/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0468 - root_mean_squared_error: 0.2162
# Epoch 91/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0612 - root_mean_squared_error: 0.2474
# Epoch 92/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0891 - root_mean_squared_error: 0.2984
# Epoch 93/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0524 - root_mean_squared_error: 0.2289
# Epoch 94/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 95/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648
# Epoch 96/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0612 - root_mean_squared_error: 0.2475
# Epoch 97/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0443 - root_mean_squared_error: 0.2105
# Epoch 98/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1107 - root_mean_squared_error: 0.3327
# Epoch 99/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0020 - root_mean_squared_error: 0.0446
# Epoch 100/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0691 - root_mean_squared_error: 0.2629
# Epoch 101/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0756 - root_mean_squared_error: 0.2749
# Epoch 102/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6313e-04 - root_mean_squared_error: 0.0162
# Epoch 103/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0580 - root_mean_squared_error: 0.2408
# Epoch 104/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0564 - root_mean_squared_error: 0.2376
# Epoch 105/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0677 - root_mean_squared_error: 0.2602
# Epoch 106/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0503 - root_mean_squared_error: 0.2244
# Epoch 107/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0404 - root_mean_squared_error: 0.2011
# Epoch 108/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0643 - root_mean_squared_error: 0.2536
# Epoch 109/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0393 - root_mean_squared_error: 0.1983
# Epoch 110/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0375 - root_mean_squared_error: 0.1937
# Epoch 111/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0597 - root_mean_squared_error: 0.2444
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0851 - root_mean_squared_error: 0.2917
# Epoch 113/200
# 14/14 [==============================] - 0s 2ms/step - loss: 6.8446e-05 - root_mean_squared_error: 0.0083
# Epoch 114/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0895 - root_mean_squared_error: 0.2992
# Epoch 115/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0351 - root_mean_squared_error: 0.1873
# Epoch 116/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0508 - root_mean_squared_error: 0.2254
# Epoch 117/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0869 - root_mean_squared_error: 0.2948
# Epoch 118/200
# 14/14 [==============================] - 0s 2ms/step - loss: 4.0753e-05 - root_mean_squared_error: 0.0064
# Epoch 119/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0775 - root_mean_squared_error: 0.2784
# Epoch 120/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0602 - root_mean_squared_error: 0.2454
# Epoch 121/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0697 - root_mean_squared_error: 0.2639
# Epoch 122/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0020 - root_mean_squared_error: 0.0448
# Epoch 123/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0901 - root_mean_squared_error: 0.3002
# Epoch 124/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503
# Epoch 125/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0657 - root_mean_squared_error: 0.2563
# Epoch 126/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0406 - root_mean_squared_error: 0.2015
# Epoch 127/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0422 - root_mean_squared_error: 0.2054
# Epoch 128/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0898 - root_mean_squared_error: 0.2997
# Epoch 129/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0255 - root_mean_squared_error: 0.1597
# Epoch 130/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0631 - root_mean_squared_error: 0.2513
# Epoch 131/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301
# Epoch 132/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0509 - root_mean_squared_error: 0.2257
# Epoch 133/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0813 - root_mean_squared_error: 0.2851
# Epoch 134/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0697
# Epoch 135/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0951 - root_mean_squared_error: 0.3084
# Epoch 136/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291
# Epoch 137/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0998 - root_mean_squared_error: 0.3160
# Epoch 138/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0657e-05 - root_mean_squared_error: 0.0045
# Epoch 139/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0764 - root_mean_squared_error: 0.2765
# Epoch 140/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0536 - root_mean_squared_error: 0.2316
# Epoch 141/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0544 - root_mean_squared_error: 0.2332
# Epoch 142/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0552 - root_mean_squared_error: 0.2349
# Epoch 143/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085
# Epoch 144/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0496 - root_mean_squared_error: 0.2226
# Epoch 145/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0904 - root_mean_squared_error: 0.3006
# Epoch 146/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970
# Epoch 147/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0727 - root_mean_squared_error: 0.2696
# Epoch 148/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0332 - root_mean_squared_error: 0.1821
# Epoch 149/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635
# Epoch 150/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0552 - root_mean_squared_error: 0.2349
# Epoch 151/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0824 - root_mean_squared_error: 0.2871
# Epoch 152/200
# 14/14 [==============================] - 0s 2ms/step - loss: 9.9679e-04 - root_mean_squared_error: 0.0316
# Epoch 153/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262
# Epoch 154/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0835 - root_mean_squared_error: 0.2890
# Epoch 155/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381
# Epoch 156/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468
# Epoch 157/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0402 - root_mean_squared_error: 0.2005
# Epoch 158/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0680 - root_mean_squared_error: 0.2609
# Epoch 159/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0362 - root_mean_squared_error: 0.1901
# Epoch 160/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0569 - root_mean_squared_error: 0.2385
# Epoch 161/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0830 - root_mean_squared_error: 0.2881
# Epoch 162/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0032 - root_mean_squared_error: 0.0570
# Epoch 163/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0842 - root_mean_squared_error: 0.2902
# Epoch 164/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0845 - root_mean_squared_error: 0.2907
# Epoch 165/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0025 - root_mean_squared_error: 0.0496
# Epoch 166/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0655 - root_mean_squared_error: 0.2560
# Epoch 167/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648
# Epoch 168/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7935e-04 - root_mean_squared_error: 0.0167
# Epoch 169/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0900 - root_mean_squared_error: 0.2999
# Epoch 170/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0641 - root_mean_squared_error: 0.2532
# Epoch 171/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0027 - root_mean_squared_error: 0.0524
# Epoch 172/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0844 - root_mean_squared_error: 0.2905
# Epoch 173/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0537 - root_mean_squared_error: 0.2316
# Epoch 174/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0277 - root_mean_squared_error: 0.1666
# Epoch 175/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0559 - root_mean_squared_error: 0.2364
# Epoch 176/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0780 - root_mean_squared_error: 0.2793
# Epoch 177/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0303 - root_mean_squared_error: 0.1741
# Epoch 178/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0736 - root_mean_squared_error: 0.2714
# Epoch 179/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0247 - root_mean_squared_error: 0.1570
# Epoch 180/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0203 - root_mean_squared_error: 0.1425
# Epoch 181/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0463 - root_mean_squared_error: 0.2153
# Epoch 182/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1037 - root_mean_squared_error: 0.3221
# Epoch 183/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2615e-06 - root_mean_squared_error: 0.0015
# Epoch 184/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0721 - root_mean_squared_error: 0.2685
# Epoch 185/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410
# Epoch 186/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0979 - root_mean_squared_error: 0.3129
# Epoch 187/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.9797e-05 - root_mean_squared_error: 0.0063
# Epoch 188/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1082 - root_mean_squared_error: 0.3290
# Epoch 189/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.6330e-04 - root_mean_squared_error: 0.0191
# Epoch 190/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0791 - root_mean_squared_error: 0.2813
# Epoch 191/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0653 - root_mean_squared_error: 0.2556
# Epoch 192/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0607 - root_mean_squared_error: 0.2464
# Epoch 193/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0205 - root_mean_squared_error: 0.1431
# Epoch 194/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0973 - root_mean_squared_error: 0.3119
# Epoch 195/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1744e-04 - root_mean_squared_error: 0.0178
# Epoch 196/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0963 - root_mean_squared_error: 0.3103
# Epoch 197/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0523 - root_mean_squared_error: 0.2288
# Epoch 198/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134
# Epoch 199/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0658 - root_mean_squared_error: 0.2565
# Epoch 200/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0378 - root_mean_squared_error: 0.1945
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# feature      label          predicted
#   kms     SellingPrice        price
# --------------------------------------
# 98.00   1.73            1.83
# 99.00   1.70            1.80
# 100.00   1.67            1.77
# 101.00   1.63            1.73
# 102.00   1.60            1.70
